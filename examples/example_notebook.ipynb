# %% [markdown]
# # Example notebook
# We can put examples in Jupyter notebooks like this one and they'll be rendered on the documentation page.
#
# The nice thing about using notebooks is that we can include math equations alongside code and figures.
#
# $$e^{i\pi} + 1 = 0$$
